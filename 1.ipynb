# %% [markdown]
# <div style="text-align:center">
#     <img src="..." height="150px">
#     <h1>Python course</h1>
#     <h3>Session 01: Variables, Expressions, Statements, Booleans, Conditions</h3>
#     <h4><a href="https://github.com/8-momo-8">metwally mohamed</a></h5>
# </div>

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ### Variables

# %% [markdown]
# <div style="text-align:center">
#     <img src="..." height="300px">
#     <h1>Ram when you run the program every thing is stored inside it</h1>
#     <img src="..." height="200px">
# </div>

# %%
myInt = 4
myReal = 2.5
myChar = "a"
myString = "hello"

print(myString)
# Out:
# hello

# %%
age = 30
name = "Mohamed"
name = "Ahmed"
print(f"Hello, I am {age} years old. My name is {name}.")
# Out:
# Hello, I am 30 years old. My name is Ahmed.

# %%
name = 3.14
print(name)

pi = 3.14
print(pi)
# Out:
# 3.14
# 3.14

# %%
price = 192.000
print(f"The book price is {price}.")
# Out:
# The book price is 192.0.

# %%
pi = 3.1415926535
print(f"Pi = {pi}")
print(f'Pi: {pi:.2f}')
print(f'Pi: {pi:.6f}')
# Out:
# Pi = 3.1415926535
# Pi: 3.14
# Pi: 3.141593

# %%
print("hello")
print('hello')
# Out:
# hello
# hello

# %%
print("----------------------------------")
print('-' * 50)
print('Hello my friend.')
print('=' * 40)
# Out:
# ----------------------------------
# --------------------------------------------------
# Hello my friend.
# ========================================

# %%
print('summer', 'time', 'holiday', sep='&')
print("summer#time#holiday")
# Out:
# summer&time&holiday
# summer#time#holiday

# %%
print('summer', 'time', 'holiday', end='!')
# Out:
# summer time holiday!

# %% [markdown]
# ### Expressions and statements

# %%
pi = 3.14
radius = 9
area = pi * radius ** 2
print(f'Area: {area:.1f}')
# Out:
# Area: 254.3

# %%
pv = 1000
r = 0.03
n = 5
fv = pv * (1 + r) ** n
print(f'The future value of the investment: {fv:.2f} USD')
# Out:
# The future value of the investment: 1159.27 USD

# %%
a = 3
b = -4
c = 5
delta = b ** 2 - 4 * a * c
print(f'Delta: {delta}')
# Out:
# Delta: -44

# %%
a1 = 14
a10 = 50
n = 10
s10 = ((a1 + a10) / 2) * n
print(f'The sum of the first 10 elements in a sequence: {s10}')
# Out:
# The sum of the first 10 elements in a sequence: 320.0

# %%
a1 = 8
a2 = 8 * 2
n = 6
q = a2 / a1
s6 = a1 * ((1 - q**n) / (1 - q))
print(f'The sum of the first {n} elements of the sequence is: {s6}')
# Out:
# The sum of the first 6 elements of the sequence is: 504.0

# %%
print(f"hello\n  world")

print("   hello")
print("world")
# Out:
# hello
#   world
#    hello
# world

# %%
a = " "
print(a)

a = "   hello"
print(a)
# Out:
#
#    hello

# %%
a = 1
b = 5
c = 4
sum = -b / a
product = c / a
print(f'x1 + x2 = {sum}\nx1x2 = {product}')
# Out:
# x1 + x2 = -5.0
# x1x2 = 4.0

# %%
a1 = 2
a2 = 4
b1 = -4
b2 = 6
s1 = (a1 + b1) / 2
s2 = (a2 + b2) / 2
print(f'The middle point: ({s1}, {s2})')
# Out:
# The middle point: (-1.0, 5.0)

# %%
a1 = 3
a2 = 2
b1 = -1
b2 = -1
distance = ((b1 - a1) ** 2 + (b2 - a2) ** 2)**(1/2)
print(f'The distance between points A and B: {distance}')
# Out:
# The distance between points A and B: 5.0

# %%
a = 1
b = 5
c = 4
delta = b ** 2 - 4 * a * c
delta_sqrt = delta ** (1/2)
x1 = (-b - delta_sqrt) / (2 * a)
x2 = (-b + delta_sqrt) / (2 * a)
print(f'x1 = {x1}')
print(f'x2 = {x2}')
# Out:
# x1 = -4.0
# x2 = -1.0

# %%
x1, x2, x3 = 10, 11, 9
mean = (x1 + x2 + x3) / 3.0
var = ((x1 - mean)**2 + (x2 - mean)**2 + (x3 - mean)**2) / 3.0
std = var**(1/2)
print(f'The standard deviation: {std:.2f}')
# Out:
# The standard deviation: 0.82

# %% [markdown]
# ### Booleans

# %%
isDay = False
isNight = True

print(isDay)
print(isNight)
# Out:
# False
# True

# %%
print(2 == 3)
# Out:
# False

# %%
print(2 != 3)
# Out:
# True

# %%
print(isDay == isNight)
print(isDay != isNight)
# Out:
# False
# True

# %%
print(isDay == True)
print(isDay == False)
# Out:
# False
# True

# %% [markdown]
# ### Data Types

# %%
var1 = ''
var2 = ' '
var3 = '\n'

print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
var1 = None
var2 = False
var3 = 'True'

print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# <class 'NoneType'>
# <class 'bool'>
# <class 'str'>

# %%
print(isinstance(var3, str))

print(isinstance(var3, bool))
# Out:
# True
# False

# %%
flag = False
print(isinstance(flag, bool))
# Out:
# True

# %% [markdown]
# ### Conditions (Control program flow)

# %% [markdown]
# <img src="..." height="400px">
# <hr/>
# <img src="..." height="400px">

# %%
a = 1

if a == 1:    
    print("a is one.")

if a == 2:
    print("a is two.")

if a > 0:
    print("a is greater than one.")

if a > 0 and a < 1:
    print("a is greater than zero and smaller than one.")
# commment
# true is 1
# false is 0
# and => *
# or => +
# 1 * 1 = 1 => true
if a > 0 and a <= 1:
    print("a is greater than zero and smaller/equal than one.")

if a > 0 or a == 1:
    print("a is zero or one.")

# 0 + 1 = 1
if a == 0 or a == 1:
    print("a is zero or one.")

# 1 + 1 = 1
if a > 0 or a == 1:
    print("a is greater than zero or it's one.")
# Out:
# a is one.
# a is greater than one.
# a is greater than zero and smaller/equal than one.
# a is zero or one.
# a is zero or one.
# a is greater than zero or it's one.

# %%
if a == 0:
    print("a is zero.")
else:
    print("a is not zero.")
# Out:
# a is not zero.

# %%
if a < 0:
    print ("a is smaller than zero.")
else:
    print("a is greater than zero.")
# Out:
# a is greater than zero.

# %%
if a < 0:
    print("a is smaller than zero.")
elif a == 0:
    print("a is zero.")
elif a == 1:
    print("a is one.")
else:
    print("a is bigger than one.")
# Out:
# a is one.

# %%
number = 1.0
if isinstance(number, int):
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
name = "Hossein"
print(len(name))
# Out:
# 7

# %%
password = 'cskdnjcasa#!'

print(len(password))

if len(password) >= 11:
    print('Password correct')
else:
    print('Password too short')
# Out:
# 12
# Password correct

# %%
password = 'cskdnjcasa#!'
if len(password) >= 11 and '!' in password:
    print('Password correct')
else:
    print('Password incorrect')
# Out:
# Password correct

# %%
filename = '01012020_sales.xlsx'
if filename.endswith('xlsx'):
    print('YES')
else:
    print('NO')
# Out:
# YES

# %%
code = 'DSVNDOICSN'
if code.isupper():
    print('Yes')
# Out:
# Yes

# %%
lang = input("What's the programming language you want to learn? ") # I wrote Python

if lang == "JavaScript":
    print("You can become a web developer.")

elif lang == "Python":
    print("You can become a Data Scientist")

elif lang == "PHP":
    print("You can become a backend developer")
    
elif lang == "Solidity":
    print("You can become a Blockchain developer")

elif lang == "Java":
    print("You can become a mobile app developer")

else:
    print("The language doesn't matter, what matters is solving problems.")
# Out:
# What's the programming language you want to learn?  Python
# You can become a Data Scientist

# %% [markdown]
# #### Switch statement (Python 3.10 and newer versions)

# %%
lang = input("What's the programming language you want to learn? \n ") # I wrote Python

match lang:
    case "JavaScript":
        print("You can become a web developer.")

    case "Python":
        print("You can become a Data Scientist")

    case "PHP":
        print("You can become a backend developer")
    
    case "Solidity":
        print("You can become a Blockchain developer")

    case "Java":
        print("You can become a mobile app developer")

    case _:
        print("The language doesn't matter, what matters is solving problems.")
# Out:
# What's the programming language you want to learn?
#   Python
# You can become a Data Scientist
